# %%
import openai
from langchain.llms import OpenAI

# %%
import os
os.environ["OPENAI_API_KEY"]="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"

# %%
llm=OpenAI(temperature=0.6)

# %%
text="who is narender modi"
print(llm.predict(text))
# Out:
# Narendra Modi is an Indian politician and the current Prime Minister of India. He is a member of the Bharatiya Janata Party (BJP) and has been in office since 2014. Prior to becoming Prime Minister, he served as the Chief Minister of Gujarat from 2001 to 2014. Modi is known for his economic policies, promoting digital and technological advancements, and his strong leadership. He is also known for his nationalist and Hindu nationalist views.

# %%
os.environ["HUGGINGFACEHUB_API_TOKEN"]="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"

# %%
from langchain import HuggingFaceHub
llm_huggingface=HuggingFaceHub(repo_id="google/flan-t5-large",model_kwargs={"temperature":0,"max_length":64})
n=input("Enter your query")
output=llm_huggingface.predict(n)
print(output)
output1=llm.predict(n)
print(output)
# Out:
# Yossi Arafat
# Yossi Arafat
