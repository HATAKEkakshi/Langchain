# %%
import openai
from langchain.llms import OpenAI

# %%
import os
os.environ["OPENAI_API_KEY"]="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"

# %%
llm=OpenAI(temperature=0.6)

# %%
text="who is narender modi"
print(llm.predict(text))
# Out:
# Narendra Modi is an Indian politician and the current Prime Minister of India. He has been in office since 2014 and is a member of the Bharatiya Janata Party (BJP). Modi was previously the Chief Minister of Gujarat from 2001 to 2014. He is known for his economic policies and focus on development, as well as his strong leadership style.

# %%
os.environ["HUGGINGFACEHUB_API_TOKEN"]="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"

# %%
from langchain import HuggingFaceHub
llm_huggingface=HuggingFaceHub(repo_id="google/flan-t5-large",model_kwargs={"temperature":0,"max_length":64})
n=input("Enter your query")
output=llm_huggingface.predict(n)
print(output)
output1=llm.predict(n)
print(output)
# Out:
# yo
# yo

# %%
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
prompt_template=PromptTemplate(input_variables=['country'],template="Tell me about the capital of {country}")
prompt_template.format(country="India")
chain=LLMChain(llm=llm,prompt=prompt_template)
n=input("Enter the country name you want to search the capital of ")
print(chain.run(n))
# Out:
# The capital of Russia is Moscow, which is located in the western part of the country on the banks of the Moskva River. It is the largest city in Russia and one of the largest cities in the world, with a population of over 12 million people.
#
# Moscow has a rich history dating back to the 12th century when it was founded by Prince Yuri Dolgorukiy. Over the centuries, it has been the center of political, cultural, and economic activity in Russia.
#
# The city is known for its iconic landmarks, including the Kremlin, Red Square, and Saint Basil's Cathedral, which are all part of the UNESCO World Heritage Site. It is also home to numerous museums, such as the State Historical Museum and the Tretyakov Gallery, which house important collections of Russian art and history.
#
# ...

# %%
from langchain.chains import LLMChain
from langchain.chains import SimpleSequentialChain
capital_prompt=PromptTemplate(input_variables=['country'],template="Tell me about the captial of {country}")
capital_chain=LLMChain(llm=llm,prompt=capital_prompt)
famous_prompt=PromptTemplate(input_variables=['capital'],template="suggest me some amazing places to visit in {capital}")
famous_chain=LLMChain(llm=llm,prompt=famous_prompt)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 7
#       5 famous_prompt=PromptTemplate(input_variables=['capital'],template="suggest me some amazing places to visit in {capital}")
#       6 famous_chain=LLMChain(llm=llm,prompt=famous_prompt)
# ----> 7 chain=SimpleSequentialChain(chains=[capital_prompt,famous_prompt])
#       8 chain.run("india")
#
# File ~/anaconda3/envs/Langchain/myenv/lib/python3.9/site-packages/langchain_core/load/serializable.py:120, in Serializable.__init__(self, **kwargs)
#     119 def __init__(self, **kwargs: Any) -> None:
# --> 120     super().__init__(**kwargs)
#     121     self._lc_kwargs = kwargs
#
# File ~/anaconda3/envs/Langchain/myenv/lib/python3.9/site-packages/pydantic/main.py:339, in pydantic.main.BaseModel.__init__()
#
# ...

# %%
from langchain.chains import SimpleSequentialChain
chain=SimpleSequentialChain(chains=[capital_chain,famous_chain])
print(chain.run("india"))
# Out:
# , New Delhi offers a unique blend of history, culture, and modernity, making it a must-visit destination for travelers. Here are some amazing places to visit in the capital city:
#
# 1. Red Fort: This iconic red sandstone fort was built by the Mughal emperor Shah Jahan in the 17th century. It is a UNESCO World Heritage Site and a popular tourist attraction, known for its intricate architecture and beautiful gardens.
#
# 2. India Gate: This war memorial is a symbol of India's rich history and sacrifice. It was built to honor the soldiers who lost their lives in World War I and the Third Afghan War. The surrounding area is a popular picnic spot for locals and tourists alike.
#
# 3. Qutub Minar: This 73-meter tall minaret is the tallest brick minaret in the world. It was built in the 12th century and is a part of the Qutub Complex, a UNESCO World Heritage Site. The complex also includes other historical structures and a beautiful garden.
#
# ...

# %%
##sequetail chain 
from langchain.chains import SequentialChain
capital_prompt=PromptTemplate(input_variables=['country'],template="Tell me about the captial of {country}")
capital_chain=LLMChain(llm=llm,prompt=capital_prompt,output_key='capital')
famous_prompt=PromptTemplate(input_variables=['capital'],template="suggest me some amazing places to visit in {capital}")
famous_chain=LLMChain(llm=llm,prompt=famous_prompt,output_key='places')
chain=SequentialChain(chains=[capital_chain,famous_chain],input_variables=['country'],output_variables=["capital","places"])
print(chain({'country':'India'}))
# Out:
# /Users/hemantkumar/anaconda3/envs/Langchain/myenv/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ...

# %%
##chatmodels and chatopenai
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage,SystemMessage,AIMessage
chatllm=ChatOpenAI(temperature=0.6,model='gpt-3.5-turbo')

# %%
chatllm([
    SystemMessage(content="You are comdeain ai assiant"),
    HumanMessage(content="please provide me a punch line")
])
# Out:
# /Users/hemantkumar/anaconda3/envs/Langchain/myenv/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# AIMessage(content='Sure thing! Here you go: "I used to play piano by ear, but now I use my hands."')

# %%
##Prompt templatre ,output paser,llm

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts.chat import ChatPromptTemplate
from langchain.schema import BaseOutputParser
class Commaseperatedouput(BaseOutputParser):
    def parse(self, text: str):
        return text.strip().split(",")

# %%
template="you are a helpful assiatant when user gives input generate 5 words synonyms seperated by commoa"
Human_template="{text}"
chatprompt=ChatPromptTemplate.from_messages([
    ("system",template),
    ("human",Human_template)
])
chain=chatprompt|chatllm|Commaseperatedouput()
chain.invoke({"text":"intelligent"})
# Out:
# ['smart', ' clever', ' astute', ' knowledgeable', ' bright']

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 chain=chatprompt|chatllm|Commaseperatedouput()
#
# NameError: name 'chatprompt' is not defined
